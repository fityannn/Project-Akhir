# %% [markdown]
# # Proyek Analisis Data: [E-Commerce Public Dataset]
# - **Nama:** Fityan Abdul Khalik
# - **Email:** fityan.abdul@gmail.com
# - **ID Dicoding:** fityannn

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk apa yang paling banyak dan paling sedikit terjual?
# - Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st

# %% [markdown]
# **Insight:** Mengimport semua packages/library yang akan digunakan

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customers_df = pd.read_csv("https://raw.githubusercontent.com/fityannn/Project-Akhir/refs/heads/main/data/customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# **Insight:**
# - Membuat tabel customers
# - 5 baris diatas menampilkan data customers

# %%
orderItems_df = pd.read_csv("https://raw.githubusercontent.com/fityannn/Project-Akhir/refs/heads/main/data/order_items_dataset.csv")
orderItems_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# **Insight:**
# - Membuat tabel orderItems
# - 5 baris diatas menampilkan data Order Items

# %%
orders_df = pd.read_csv("https://raw.githubusercontent.com/fityannn/Project-Akhir/refs/heads/main/data/orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# **Insight:**
# - Membuat tabel orders
# - 5 baris diatas menampilkan data orders

# %%
product_df = pd.read_csv("https://raw.githubusercontent.com/fityannn/Project-Akhir/refs/heads/main/data/products_dataset.csv")
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# **Insight:**
# - Membuat tabel product
# - 5 baris diatas menampilkan data product

# %%
seller_df = pd.read_csv("https://raw.githubusercontent.com/fityannn/Project-Akhir/refs/heads/main/data/sellers_dataset.csv")
seller_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# **Insight:**
# - Membuat tabel seller
# - 5 baris diatas menampilkan data seller

# %% [markdown]
# ### Assessing Data
# ### Menilai tabel customers_df

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# **insight:**
# Memeriksa tipe data data dari tiap kolom yang terdapat dalam customers_df.

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# **insight:**
# Memeriksa apakah ada missing values dari tiap kolom yang terdapat dalam customers_df.

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# **insight:**
# Memeriksa apakah ada duplikasi dari tiap kolom yang terdapat dalam customers_df.

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# **insight:**
# Memeriksa parameter statistik dari kolom numerik yang terdapat dalam customers_df.

# %% [markdown]
# ### Menilai tabel orderItems_df

# %%
orderItems_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# **insight:**
# Memeriksa tipe data data dari tiap kolom yang terdapat dalam orderItems_df.

# %%
orderItems_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# **insight:**
# Memeriksa apakah ada missing values dari tiap kolom yang terdapat dalam orderItems_df.

# %%
print("Jumlah duplikasi: ", orderItems_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# **insight:**
# Memeriksa apakah ada duplikasi dari tiap kolom yang terdapat dalam orderItems_df.

# %%
orderItems_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# **insight:**
# Memeriksa parameter statistik dari kolom numerik yang terdapat dalam orderItems_df.

# %% [markdown]
# ## Menilai Tabel orders_df

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# **insight:**
# Memeriksa tipe data data dari tiap kolom yang terdapat dalam orders_df.

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# **insight:**
# Memeriksa apakah ada missing values dari tiap kolom yang terdapat dalam orders_df.

# %%
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# **insight:**
# Memeriksa apakah ada duplikasi dari tiap kolom yang terdapat dalam orders_df.

# %%
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# **insight:**
# Memeriksa parameter statistik dari kolom numerik yang terdapat dalam orders_df.

# %% [markdown]
# ## Menilai Tabel product_df

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# **insight:**
# Memeriksa tipe data data dari tiap kolom yang terdapat dalam product_df.

# %%
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# **insight:**
# Memeriksa apakah ada missing values dari tiap kolom yang terdapat dalam product_df.

# %%
print("Jumlah duplikasi: ", product_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# **insight:**
# Memeriksa apakah ada duplikasi dari tiap kolom yang terdapat dalam product_df.

# %%
product_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# **insight:**
# Memeriksa parameter statistik dari kolom numerik yang terdapat dalam product_df.

# %% [markdown]
# ## Menilai Tabel seller_df

# %%
seller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# **insight:**
# Memeriksa tipe data data dari tiap kolom yang terdapat dalam seller_df.

# %%
seller_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %% [markdown]
# **insight:**
# Memeriksa apakah ada missing values dari tiap kolom yang terdapat dalam seller_df.

# %%
print("Jumlah duplikasi: ", seller_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# **insight:**
# Memeriksa apakah ada duplikasi dari tiap kolom yang terdapat dalam seller_df.

# %%
seller_df.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# **insight:**
# Memeriksa parameter statistik dari kolom numerik yang terdapat dalam seller_df.

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ## Membersihkan Tabel orders_df
# ### missing values

# %%
datetime_columns = ["order_purchase_timestamp","order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %% [markdown]
# **Insight:** Merubah columns-columns diatas menjadi datetime dalam orders_df

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# **Insight:** mengecek apakah columns-columns tadi sudah berubah menjadi datetime dalam orders_df

# %%
orders_df[orders_df.order_approved_at.isna()]
orders_df[orders_df.order_delivered_carrier_date.isna()]
orders_df[orders_df.order_delivered_customer_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# **Insight:** mengecek dan menangani missing value yang terdapat di columns-columns tersebut yang terdapat di dalam orders_df

# %%
orders_df.order_approved_at.value_counts()
# Out:
# order_approved_at
# 2018-02-27 04:31:10    9
# 2017-11-07 07:30:38    7
# 2018-02-27 04:31:01    7
# 2018-02-06 05:31:52    7
# 2017-11-07 07:30:29    7
#                       ..
# 2018-08-22 11:50:14    1
# 2017-09-22 11:27:36    1
# 2018-03-07 16:40:32    1
# 2017-08-08 10:50:15    1
# 2018-03-09 11:20:28    1
# Name: count, Length: 90733, dtype: int64

# %% [markdown]
# **Insight:**
# - Mencari nilai yang dominan di order_approved_at, sehingga dapat digunakan sebagai pengganti missing value
# - Menggunakan method value_counts() untuk mengidentifikasi nilai yang dominan.

# %%
orders_df.order_delivered_carrier_date.value_counts()
# Out:
# order_delivered_carrier_date
# 2018-05-09 15:48:00    47
# 2018-05-10 18:29:00    32
# 2018-05-07 12:31:00    21
# 2018-05-02 15:15:00    16
# 2018-07-24 16:07:00    16
#                        ..
# 2018-01-03 17:37:21     1
# 2017-10-27 20:07:58     1
# 2017-11-21 18:57:37     1
# 2018-03-21 20:03:37     1
# 2018-03-09 22:11:59     1
# Name: count, Length: 81018, dtype: int64

# %% [markdown]
# **Insight:**
# - Mencari nilai yang dominan di order_delivered_carrier_date, sehingga dapat digunakan sebagai pengganti missing value
# - Menggunakan method value_counts() untuk mengidentifikasi nilai yang dominan.

# %%
orders_df.order_delivered_customer_date.value_counts()
# Out:
# order_delivered_customer_date
# 2018-05-08 23:38:46    3
# 2016-10-27 17:32:07    3
# 2018-02-14 21:09:19    3
# 2017-06-19 18:47:51    3
# 2018-05-08 19:36:48    3
#                       ..
# 2018-07-12 17:48:45    1
# 2018-05-18 18:24:36    1
# 2018-01-17 13:29:13    1
# 2018-06-29 11:21:34    1
# 2018-03-16 13:08:30    1
# Name: count, Length: 95664, dtype: int64

# %% [markdown]
# **Insight:**
# - Mencari nilai yang dominan di order_delivered_customer_date, sehingga dapat digunakan sebagai pengganti missing value
# - Menggunakan method value_counts() untuk mengidentifikasi nilai yang dominan.

# %%
orders_df["order_approved_at"] = orders_df["order_approved_at"].fillna(pd.to_datetime("2018-02-27 04:31:10"))

# %% [markdown]
# **Insight:**
# - Menggunakan "2018-02-27 04:31:10" untuk mengganti nilai missing value, dikarenakan nilai tersebut merupakan nilai yang dominan.
# - menggunakan metode fillna() untuk mengganti nilai tersebut.

# %%
orders_df["order_delivered_carrier_date"] = orders_df["order_delivered_carrier_date"].fillna(pd.to_datetime("2018-05-09 15:48:00"))

# %% [markdown]
# **Insight:**
# - Menggunakan "2018-05-09 15:48:00" untuk mengganti nilai missing value, dikarenakan nilai tersebut merupakan nilai yang dominan.
# - menggunakan metode fillna() untuk mengganti nilai tersebut.

# %%
orders_df["order_delivered_customer_date"] = orders_df["order_delivered_customer_date"].fillna(pd.to_datetime("2018-05-08 23:38:46"))

# %% [markdown]
# **Insight:**
# - Menggunakan "2018-05-08 23:38:46" untuk mengganti nilai missing value, dikarenakan nilai tersebut merupakan nilai yang dominan.
# - menggunakan metode fillna() untuk mengganti nilai tersebut.

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# **Insight:** Mengecek apakah nilai missing value masih ada.

# %% [markdown]
# ## Membersihkan product_df
# ## Missing Value

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# **Insight:** Mengecek data tipe dalam columns product_df.

# %%
product_df[product_df.product_category_name.isna()]
product_df[product_df.product_name_lenght.isna()]
product_df[product_df.product_description_lenght.isna()]
product_df[product_df.product_photos_qty.isna()]
product_df[product_df.product_weight_g.isna()]
product_df[product_df.product_length_cm.isna()]
product_df[product_df.product_height_cm.isna()]
product_df[product_df.product_width_cm.isna()]
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %% [markdown]
# **Insight:** Mengecek apakah ada missing value yang terdapat dalam product_df.

# %%
product_df.product_category_name.value_counts()
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %% [markdown]
# **Insight:**
# - Mencari nilai yang dominan di product_category_name, sehingga dapat digunakan sebagai pengganti missing value
# - Menggunakan method value_counts() untuk mengidentifikasi nilai yang dominan.

# %%
product_df.product_name_lenght.value_counts()
# Out:
# product_name_lenght
# 60.0    2182
# 59.0    2025
# 58.0    1887
# 57.0    1719
# 55.0    1683
#         ...
# 66.0       1
# 72.0       1
# 67.0       1
# 76.0       1
# 6.0        1
# Name: count, Length: 66, dtype: int64

# %% [markdown]
# **Insight:**
# - Mencari nilai yang dominan di product_name_lenght, sehingga dapat digunakan sebagai pengganti missing value
# - Menggunakan method value_counts() untuk mengidentifikasi nilai yang dominan.

# %%
product_df.product_description_lenght.value_counts()
# Out:
# product_description_lenght
# 404.0     94
# 729.0     86
# 651.0     66
# 703.0     66
# 236.0     65
#           ..
# 2795.0     1
# 2308.0     1
# 3698.0     1
# 3522.0     1
# 2207.0     1
# Name: count, Length: 2960, dtype: int64

# %% [markdown]
# **Insight:**
# - Mencari nilai yang dominan di product_description_lenght, sehingga dapat digunakan sebagai pengganti missing value
# - Menggunakan method value_counts() untuk mengidentifikasi nilai yang dominan.

# %%
product_df.product_photos_qty.value_counts()
# Out:
# product_photos_qty
# 1.0     16489
# 2.0      6263
# 3.0      3860
# 4.0      2428
# 5.0      1484
# 6.0       968
# 7.0       343
# 8.0       192
# 9.0       105
# 10.0       95
# 11.0       46
# 12.0       35
# 13.0        9
# 15.0        8
# 17.0        7
# 14.0        5
# 18.0        2
# 20.0        1
# 19.0        1
# Name: count, dtype: int64

# %% [markdown]
# **Insight:**
# - Mencari nilai yang dominan di product_photos_qty, sehingga dapat digunakan sebagai pengganti missing value
# - Menggunakan method value_counts() untuk mengidentifikasi nilai yang dominan.

# %%
product_df.product_weight_g.value_counts()
# Out:
# product_weight_g
# 200.0     2084
# 300.0     1561
# 150.0     1259
# 400.0     1206
# 100.0     1188
#           ...
# 6075.0       1
# 822.0        1
# 631.0        1
# 2925.0       1
# 1920.0       1
# Name: count, Length: 2204, dtype: int64

# %% [markdown]
# **Insight:**
# - Mencari nilai yang dominan di product_weight_g, sehingga dapat digunakan sebagai pengganti missing value
# - Menggunakan method value_counts() untuk mengidentifikasi nilai yang dominan.

# %%
product_df.product_length_cm.value_counts()
# Out:
# product_length_cm
# 16.0    5520
# 20.0    2816
# 30.0    2029
# 18.0    1502
# 25.0    1387
#         ...
# 96.0       4
# 10.0       3
# 8.0        2
# 9.0        2
# 7.0        1
# Name: count, Length: 99, dtype: int64

# %% [markdown]
# **Insight:**
# - Mencari nilai yang dominan di product_length_cm, sehingga dapat digunakan sebagai pengganti missing value
# - Menggunakan method value_counts() untuk mengidentifikasi nilai yang dominan.

# %%
product_df.product_height_cm.value_counts()
# Out:
# product_height_cm
# 10.0    2548
# 15.0    2022
# 20.0    1991
# 16.0    1595
# 11.0    1551
#         ...
# 98.0       2
# 97.0       2
# 99.0       1
# 89.0       1
# 94.0       1
# Name: count, Length: 102, dtype: int64

# %% [markdown]
# **Insight:**
# - Mencari nilai yang dominan di product_height_cm, sehingga dapat digunakan sebagai pengganti missing value
# - Menggunakan method value_counts() untuk mengidentifikasi nilai yang dominan.

# %%
product_df.product_width_cm.value_counts()
# Out:
# product_width_cm
# 11.0     3718
# 20.0     3053
# 16.0     2808
# 15.0     2393
# 30.0     1786
#          ...
# 103.0       1
# 86.0        1
# 98.0        1
# 87.0        1
# 104.0       1
# Name: count, Length: 95, dtype: int64

# %% [markdown]
# **Insight:**
# - Mencari nilai yang dominan di product_width_cm, sehingga dapat digunakan sebagai pengganti missing value
# - Menggunakan method value_counts() untuk mengidentifikasi nilai yang dominan.

# %%
product_df["product_category_name"] = product_df["product_category_name"].fillna("cama_mesa_banho")

# %% [markdown]
# **Insight:**
# - Menggunakan "cama_mesa_banho" untuk mengganti nilai missing value, dikarenakan nilai tersebut merupakan nilai yang dominan.
# - menggunakan metode fillna() untuk mengganti nilai tersebut.

# %%
product_df["product_name_lenght"] = product_df["product_name_lenght"].fillna("60.0")

# %% [markdown]
# **Insight:**
# - Menggunakan "60.0" untuk mengganti nilai missing value, dikarenakan nilai tersebut merupakan nilai yang dominan.
# - menggunakan metode fillna() untuk mengganti nilai tersebut.

# %%
product_df["product_description_lenght"] = product_df["product_description_lenght"].fillna("404.0")

# %% [markdown]
# **Insight:**
# - Menggunakan "404.0" untuk mengganti nilai missing value, dikarenakan nilai tersebut merupakan nilai yang dominan.
# - menggunakan metode fillna() untuk mengganti nilai tersebut.

# %%
product_df["product_photos_qty"] = product_df["product_photos_qty"].fillna("1.0")

# %% [markdown]
# **Insight:**
# - Menggunakan "1.0" untuk mengganti nilai missing value, dikarenakan nilai tersebut merupakan nilai yang dominan.
# - menggunakan metode fillna() untuk mengganti nilai tersebut.

# %%
product_df["product_weight_g"] = product_df["product_weight_g"].fillna("200.0")

# %% [markdown]
# **Insight:**
# - Menggunakan "200.0" untuk mengganti nilai missing value, dikarenakan nilai tersebut merupakan nilai yang dominan.
# - menggunakan metode fillna() untuk mengganti nilai tersebut.

# %%
product_df["product_length_cm"] = product_df["product_length_cm"].fillna("16.0")

# %% [markdown]
# **Insight:**
# - Menggunakan "16.0" untuk mengganti nilai missing value, dikarenakan nilai tersebut merupakan nilai yang dominan.
# - menggunakan metode fillna() untuk mengganti nilai tersebut.

# %%
product_df["product_height_cm"] = product_df["product_height_cm"].fillna("10.0")

# %% [markdown]
# **Insight:**
# - Menggunakan "10.0" untuk mengganti nilai missing value, dikarenakan nilai tersebut merupakan nilai yang dominan.
# - menggunakan metode fillna() untuk mengganti nilai tersebut.

# %%
product_df["product_width_cm"] = product_df["product_width_cm"].fillna("11.0")

# %% [markdown]
# **Insight:**
# - Menggunakan "11.0" untuk mengganti nilai missing value, dikarenakan nilai tersebut merupakan nilai yang dominan.
# - menggunakan metode fillna() untuk mengganti nilai tersebut.

# %%
product_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# **Insight:** Mengecek apakah masih ada missing value di dalam columns tersebut.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore customers_df

# %%
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 93651  59b5b2d3fb1c8928920f6f3ff243e3c9  c28f4785ee1f68c298874a466cc1445f
# 57127  a64f98b1b0d8e2ca4cba10a0a2adb3c8  48fb6bd698dd6bdd87a263c713f0b1e0
# 29603  d11f59faed0f745f357e502c28bacfaa  2d9e2f6bc85722a5fdaa5f9b14f4595a
# 4214   46bcc20ccc04bf316305ef8aa6f59d4d  7c9f20c08a4bc9d2e7337e87e29de2f2
# 63887  721a29f8fd580ecc0ffa77c1eb55c653  5b2f6d16df47dae251b6808c945f9d54
#
#        customer_zip_code_prefix         customer_city customer_state
# 93651                     41815              salvador             BA
# 57127                     32405               ibirite             MG
# 29603                     13324                 salto             SP
# 4214                       6850  itapecerica da serra             SP
# 63887                     13070              campinas             SP

# %% [markdown]
# **Insight:** Memperlihatkan 5 rows dari columns-columns yang berada di customer_df.

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# **Insight:** Menggunakan describe(includes="all") untuk melihat rangkuman parameter statistik dari customers_df.

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# **Insight:** Melihat persebaran jumlah pelanggan berdasarkan kota pelanggan (customer_city) dan menampilkannya dengan *descending*

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# **Insight:** Melihat persebaran jumlah pelanggan berdasarkan negara pelanggan (customer_state) dan menampilkannya dengan *descending*

# %% [markdown]
# ### explore orders_df

# %%
delivery_time = orders_df["order_delivered_customer_date"] - orders_df["order_approved_at"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %% [markdown]
# **Insight:** Membuat sebuah kolom baru untuk memuat waktu pengiriman tiap order. Untuk melakukannya, kita perlu menghitung selisih antar order_delivered_customer_date dan order_approved_at serta menyimpannya sebagai delivery_time.

# %%
orders_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %% [markdown]
# **Insight:** Melihat rangkuman parameter statistik dari orders_df.

# %% [markdown]
# ## Eksplorasi Data orders_df dan customers_df

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# **Insight:**
# - Melakukan merge terhadap orders_df dan customers_df
# - 5 tabel diatas adalah gabungan dari orders_df dan customers_df

# %%
orders_customers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#            customer_city  order_id
# 0              sao paulo     15540
# 1         rio de janeiro      6882
# 2         belo horizonte      2773
# 3               brasilia      2131
# 4               curitiba      1521
# 5               campinas      1444
# 6           porto alegre      1379
# 7               salvador      1245
# 8              guarulhos      1189
# 9  sao bernardo do campo       938

# %% [markdown]
# **Insight:**
#  Tabel diatas adalah pivot table yang tercipta berdasarkan kota pelanggan

# %%
orders_customers_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: order_id, dtype: int64

# %% [markdown]
# **Insight:**
#  Tabel diatas adalah pivot table yang tercipta berdasarkan negara pelanggan

# %% [markdown]
# ## Eksplorasi Data product_df dan orderItems_df

# %%
order_product_df = pd.merge(
    left=orderItems_df,
    right=product_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
order_product_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %% [markdown]
# **Insight:**
# - Melakukan merge terhadap product_df dan orderItems_df
# - 5 tabel diatas adalah gabungan dari product_df dan orderItems_df

# %%
order_product_df.groupby(by="price").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#    price  order_id
# 0   59.9      2087
# 1   69.9      1821
# 2   49.9      1675
# 3   89.9      1419
# 4   99.9      1319
# 5   39.9      1159
# 6   29.9      1136
# 7   79.9      1122
# 8   19.9      1060
# 9   49.0      1021

# %% [markdown]
# **Insight:**
#  Tabel diatas adalah pivot table yang tercipta berdasarkan harga

# %%
order_product_df.groupby(by="product_category_name").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#     product_category_name  order_id
# 0         cama_mesa_banho     10860
# 1            beleza_saude      8836
# 2           esporte_lazer      7720
# 3  informatica_acessorios      6689
# 4        moveis_decoracao      6449
# 5   utilidades_domesticas      5884
# 6      relogios_presentes      5624
# 7               telefonia      4199
# 8              automotivo      3897
# 9              brinquedos      3886

# %% [markdown]
# **Insight:**
#  Tabel diatas adalah pivot table yang tercipta berdasarkan nama kategori produk

# %% [markdown]
# ## Membuat all_df

# %%
all_df = pd.merge(
    left=orders_customers_df,
    right=order_product_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Produk Apa yang Paling Banyak dan Paling Sedikit Terjual?

# %%
sum_order_items_df = order_product_df.groupby(by="product_category_name").order_id.nunique().sort_values(ascending=False).reset_index()
sum_order_items_df.head(15)
# Out:
#      product_category_name  order_id
# 0          cama_mesa_banho     10860
# 1             beleza_saude      8836
# 2            esporte_lazer      7720
# 3   informatica_acessorios      6689
# 4         moveis_decoracao      6449
# 5    utilidades_domesticas      5884
# 6       relogios_presentes      5624
# 7                telefonia      4199
# 8               automotivo      3897
# 9               brinquedos      3886
# 10              cool_stuff      3632
# 11      ferramentas_jardim      3518
# 12              perfumaria      3162
# 13                   bebes      2885
# 14             eletronicos      2550

# %% [markdown]
# **Insight:** Membuat DataFrame baru untuk menampung informasi terkait jumlah penjualan tiap produk.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="order_id", y="product_category_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="order_id", y="product_category_name", data=sum_order_items_df.sort_values(by="order_id", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()
# Out:
# <ipython-input-731-4acefe01679e>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="order_id", y="product_category_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# **Insight:** Membuat visualisasi data dalam bentuk bar chart.

# %% [markdown]
# ### Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?

# %%
order_product_df['shipping_limit_date'] = pd.to_datetime(order_product_df['shipping_limit_date'])

monthly_orders_df = order_product_df.resample(rule='M', on='shipping_limit_date').agg({
    "order_id": "nunique",
    "price": "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%Y-%m')
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "price": "revenue"
}, inplace=True)
monthly_orders_df.head()
# Out:
# <ipython-input-732-19783386bdcb>:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_orders_df = order_product_df.resample(rule='M', on='shipping_limit_date').agg({
#   shipping_limit_date  order_count   revenue
# 0             2016-09            2    194.47
# 1             2016-10          309  49580.55
# 2             2016-11            0      0.00
# 3             2016-12            1     10.90
# 4             2017-01          573  80124.74

# %% [markdown]
# **Insight:** Merubah frekuensi data untuk memperoleh informasi terkait jumlah order dan total revenue yang diperoleh setiap bulannya.

# %%
monthly_orders_df['shipping_limit_date'] = pd.to_datetime(monthly_orders_df['shipping_limit_date'], format='%Y-%m')

# Filter the DataFrame for the desired date range (September 2017 to September 2018)
start_date = '2017-09-01'
end_date = '2018-09-30'
filtered_orders_df = monthly_orders_df[(monthly_orders_df['shipping_limit_date'] >= start_date) &
                                        (monthly_orders_df['shipping_limit_date'] <= end_date)]

# Set up the plot
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Plot with fill
plt.plot(filtered_orders_df['shipping_limit_date'],
         filtered_orders_df['order_count'],
         marker='o',
         linewidth=2,
         color="#72BCD4")

plt.fill_between(filtered_orders_df['shipping_limit_date'],
                 filtered_orders_df['order_count'],
                 color="#B2E0EB", alpha=0.3)

# Title and labels
plt.title("Pembelian dari 2017 sampai 2018", fontsize=24, loc='center')
plt.xticks(filtered_orders_df['shipping_limit_date'],
           filtered_orders_df['shipping_limit_date'].dt.strftime('%B %Y'),
           rotation=45)
plt.xlabel("Month", fontsize=16)
plt.ylabel("Number of Orders", fontsize=16)

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Annotate the highest point if there are any orders
if not filtered_orders_df.empty:
    max_orders = filtered_orders_df['order_count'].max()
    max_month = filtered_orders_df['shipping_limit_date'][filtered_orders_df['order_count'].idxmax()]
    plt.annotate(f'Max: {max_orders}',
                 xy=(max_month, max_orders),
                 xytext=(max_month, max_orders + 20),
                 arrowprops=dict(facecolor='black', shrink=0.05),
                 fontsize=12,
                 color='black',
                 horizontalalignment='center')

plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %% [markdown]
# **Insight:** Menggunakan line chart untuk memvisualkan informasi terkait jumlah order dan total revenue yang diperoleh tiap bulan.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Produk yang paling banyak terjual adalah cama_mesa_banho, sedangkan produk yang paling sedikit terjual adalah seguros_e_servicos
# - Pembelian barang terbanyak terdapat di bulan Agustus dengan 7823 pembelian

# %%
all_df.to_csv("all_data.csv", index=False)
